# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
rd=pd.read_csv(r"C:\Users\USER\Downloads\Country-data.csv")
rd
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %%
rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     167 non-null    object
#  1   child_mort  167 non-null    float64
#  2   exports     167 non-null    float64
#  3   health      167 non-null    float64
#  4   imports     167 non-null    float64
#  5   income      167 non-null    int64
#  6   inflation   167 non-null    float64
#  7   life_expec  167 non-null    float64
#  8   total_fer   167 non-null    float64
#  9   gdpp        167 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 13.2+ KB

# %%
rd.isna().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %%
df=rd.drop('country',axis=1)
df
# Out:
#      child_mort  exports  health  imports  income  inflation  life_expec  \
# 0          90.2     10.0    7.58     44.9    1610       9.44        56.2
# 1          16.6     28.0    6.55     48.6    9930       4.49        76.3
# 2          27.3     38.4    4.17     31.4   12900      16.10        76.5
# 3         119.0     62.3    2.85     42.9    5900      22.40        60.1
# 4          10.3     45.5    6.03     58.9   19100       1.44        76.8
# ..          ...      ...     ...      ...     ...        ...         ...
# 162        29.2     46.6    5.25     52.7    2950       2.62        63.0
# 163        17.1     28.5    4.91     17.6   16500      45.90        75.4
# 164        23.3     72.0    6.84     80.2    4490      12.10        73.1
# 165        56.3     30.0    5.18     34.4    4480      23.60        67.5
# 166        83.1     37.0    5.89     30.9    3280      14.00        52.0
#
#      total_fer   gdpp
# 0         5.82    553
# 1         1.65   4090
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df=pd.DataFrame(scaler.fit_transform(df),columns=df.columns)
df
# Out:
#      child_mort   exports    health   imports    income  inflation  \
# 0      1.291532 -1.138280  0.279088 -0.082455 -0.808245   0.157336
# 1     -0.538949 -0.479658 -0.097016  0.070837 -0.375369  -0.312347
# 2     -0.272833 -0.099122 -0.966073 -0.641762 -0.220844   0.789274
# 3      2.007808  0.775381 -1.448071 -0.165315 -0.585043   1.387054
# 4     -0.695634  0.160668 -0.286894  0.497568  0.101732  -0.601749
# ..          ...       ...       ...       ...       ...        ...
# 162   -0.225578  0.200917 -0.571711  0.240700 -0.738527  -0.489784
# 163   -0.526514 -0.461363 -0.695862 -1.213499 -0.033542   3.616865
# 164   -0.372315  1.130305  0.008877  1.380030 -0.658404   0.409732
# 165    0.448417 -0.406478 -0.597272 -0.517472 -0.658924   1.500916
# 166    1.114951 -0.150348 -0.338015 -0.662477 -0.721358   0.590015
#
#      life_expec  total_fer      gdpp
# 0     -1.619092   1.902882 -0.679180
# 1      0.647866  -0.859973 -0.485623
# 2      0.670423  -0.038404 -0.465376
# ...

# %% [markdown]
# # KMeans Clustering

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)
wcss
# Out:
# C:\Users\USER\anaconda31\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# [1503.0000000000002,
#  1050.2145582853307,
#  831.424435208687,
#  700.3229986404373,
#  620.163371288842,
#  571.9992966496745,
#  495.3233825951917,
#  455.27682760469946,
#  426.45844564714764,
#  396.25069895342983]

# %%
plt.plot(range(1,11),wcss,'-o')
plt.xlabel('no of clusters')
plt.ylabel('wcss')
plt.title('Elbow plot')
# Out:
# Text(0.5, 1.0, 'Elbow plot')

# %%
kmeans=KMeans(n_clusters=4)
kmeans.fit(df)
labels=kmeans.predict(df)
print(labels)
# Out:
# [1 2 2 1 2 2 2 0 0 2 2 2 2 2 2 0 2 1 2 2 2 2 2 0 2 1 1 2 1 0 2 1 1 2 2 2 1
#  1 1 2 1 2 0 2 0 2 2 2 2 1 1 2 2 0 0 1 1 2 0 1 0 2 2 1 1 2 1 2 0 2 2 2 1 0
#  0 0 2 0 2 2 1 1 0 2 1 2 2 1 1 2 2 3 2 1 1 2 2 1 3 1 2 2 2 2 2 2 1 1 1 2 0
#  0 1 1 0 2 1 2 2 2 2 2 0 0 2 2 1 2 2 1 2 2 1 3 2 0 2 1 0 0 2 2 1 2 0 0 2 1
#  2 1 1 2 2 2 2 1 2 0 0 0 2 2 2 2 2 1 1]

# %%
label = pd.DataFrame(labels)
label= label.rename(columns = {0: 'label'})
label
# Out:
#      label
# 0        1
# 1        2
# 2        2
# 3        1
# 4        2
# ..     ...
# 162      2
# 163      2
# 164      2
# 165      1
# 166      1
#
# [167 rows x 1 columns]

# %%
label.value_counts()
# Out:
# label
# 2        87
# 1        47
# 0        30
# 3         3
# dtype: int64

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
reduced_df=pd.DataFrame(pca.fit_transform(df),columns=['PC1','PC2'])
reduced_df
# Out:
#           PC1       PC2
# 0   -2.913025  0.095621
# 1    0.429911 -0.588156
# 2   -0.285225 -0.455174
# 3   -2.932423  1.695555
# 4    1.033576  0.136659
# ..        ...       ...
# 162 -0.820631  0.639570
# 163 -0.551036 -1.233886
# 164  0.498524  1.390744
# 165 -1.887451 -0.109453
# 166 -2.864064  0.485998
#
# [167 rows x 2 columns]

# %%
reduced_df['cluster_km']=label

reduced_df
# Out:
#           PC1       PC2  cluster_km
# 0   -2.913025  0.095621           1
# 1    0.429911 -0.588156           2
# 2   -0.285225 -0.455174           2
# 3   -2.932423  1.695555           1
# 4    1.033576  0.136659           2
# ..        ...       ...         ...
# 162 -0.820631  0.639570           2
# 163 -0.551036 -1.233886           2
# 164  0.498524  1.390744           2
# 165 -1.887451 -0.109453           1
# 166 -2.864064  0.485998           1
#
# [167 rows x 3 columns]

# %%
red_centers=pca.transform(kmeans.cluster_centers_)
red_centers
# Out:
# array([[ 2.58590537, -0.86669   ],
#        [-2.45494144,  0.36721104],
#        [ 0.24625762, -0.08684643],
#        [ 5.46022462,  5.43247334]])

# %%
plt.figure(figsize=(14,10))
plt.scatter(reduced_rd['PC1'],reduced_rd['PC2'])
plt.scatter(reduced_rd[reduced_rd['cluster_km']==0].loc[:,'PC1'],reduced_rd[reduced_rd['cluster_km']==0].loc[:,'PC2'],color='red',label='cluster 0')
plt.scatter(reduced_rd[reduced_rd['cluster_km']==1].loc[:,'PC1'],reduced_rd[reduced_rd['cluster_km']==1].loc[:,'PC2'],color='indigo',label='cluster 1')
plt.scatter(reduced_rd[reduced_rd['cluster_km']==2].loc[:,'PC1'],reduced_rd[reduced_rd['cluster_km']==2].loc[:,'PC2'],color='green',label='cluster 2')
plt.scatter(reduced_rd[reduced_rd['cluster_km']==3].loc[:,'PC1'],reduced_rd[reduced_rd['cluster_km']==3].loc[:,'PC2'],color='blue',label='cluster 3')

plt.scatter(red_centers[:,0],red_centers[:,1],color='black',marker='x',s=100)
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.legend()

# %%
rd['cluster']=reduced_df['cluster_km']
rd
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp  cluster
# 0         9.44        56.2       5.82    553        1
# ...

# %%
rd.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp     cluster
# count  167.000000  167.000000  167.000000     167.000000  167.000000
# mean     7.781832   70.555689    2.947964   12964.155689    1.377246
# std     10.570704    8.893172    1.513848   18328.704809    0.796202
# min     -4.210000   32.100000    1.150000     231.000000    0.000000
# ...

# %%
rd[['country', 'cluster']].loc[rd['child_mort'] > 70]
# Out:
#                       country  cluster
# 0                 Afghanistan        1
# 3                      Angola        1
# 17                      Benin        1
# 25               Burkina Faso        1
# 26                    Burundi        1
# 28                   Cameroon        1
# 31   Central African Republic        1
# 32                       Chad        1
# 36                    Comoros        1
# 37           Congo, Dem. Rep.        1
# 40              Cote d'Ivoire        1
# 49          Equatorial Guinea        1
# 56                     Gambia        1
# 59                      Ghana        1
# 63                     Guinea        1
# 64              Guinea-Bissau        1
# 66                      Haiti        1
# 84                        Lao        1
# 87                    Lesotho        1
# 88                    Liberia        1
# 94                     Malawi        1
# 97                       Mali        1
# 99                 Mauritania        1
# ...

# %%
rd[['country', 'cluster']].loc[rd['health'] < 3]
# Out:
#           country  cluster
# 3          Angola        1
# 23         Brunei        0
# 38    Congo, Rep.        1
# 50        Eritrea        1
# 70      Indonesia        2
# 82         Kuwait        0
# 107       Myanmar        1
# 115          Oman        2
# 116      Pakistan        1
# 123         Qatar        0
# 140     Sri Lanka        2
# 154  Turkmenistan        2

# %%
rd[[ 'cluster']].loc[rd['health'] < 3].value_counts()
# Out:
# cluster
# 1          5
# 2          4
# 0          3
# dtype: int64

# %%
rd[['country', 'cluster']].loc[rd['income'] < 1000]
# Out:
#                       country  cluster
# 26                    Burundi        1
# 31   Central African Republic        1
# 37           Congo, Dem. Rep.        1
# 88                    Liberia        1
# 106                Mozambique        1
# 112                     Niger        1

# %%
rd[['country', 'cluster']].loc[rd['life_expec'] < 50]
# Out:
#                      country  cluster
# 31  Central African Republic        1
# 66                     Haiti        1
# 87                   Lesotho        1

# %% [markdown]
# ***The countries in cluster 1 have the lowest socio-economic and health ratings.***

# %%
rd['country'].loc[rd['cluster']==1]
# Out:
# 0                   Afghanistan
# 3                        Angola
# 17                        Benin
# 25                 Burkina Faso
# 26                      Burundi
# 28                     Cameroon
# 31     Central African Republic
# 32                         Chad
# 36                      Comoros
# 37             Congo, Dem. Rep.
# 38                  Congo, Rep.
# 40                Cote d'Ivoire
# 49            Equatorial Guinea
# 50                      Eritrea
# 55                        Gabon
# 56                       Gambia
# 59                        Ghana
# 63                       Guinea
# 64                Guinea-Bissau
# 66                        Haiti
# 72                         Iraq
# 80                        Kenya
# 81                     Kiribati
# 84                          Lao
# 87                      Lesotho
# 88                      Liberia
# 93                   Madagascar
# 94                       Malawi
# 97                         Mali
# ...

# %% [markdown]
# ***These are the countries ,included in cluster 1, which are in the need of direct aid.***
